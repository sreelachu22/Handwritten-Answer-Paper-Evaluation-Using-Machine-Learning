# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# database creation

# %%
import sqlite3

conn = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')  # You can create a new database by changing the name within the quotes
c = conn.cursor() # The database will be saved in the location where your 'py' file is saved

# Create table - CLIENTS
c.execute('''CREATE TABLE exam_db
             ([examid] INTEGER PRIMARY KEY, [subid] text, [totalmark] integer)''')
c.execute('''CREATE TABLE question_db
             ([examid] INTEGER, [qno] integer, [question] text, [modelans] text, [maxmark] integer, PRIMARY KEY(examid,qno))''')
c.execute('''CREATE TABLE score_db
             ([examid] INTEGER, [rollno] integer, [qno] integer, [answer] text, [mark] integer,  PRIMARY KEY(examid,rollno,qno))''')
c.execute('''CREATE TABLE answer_db
             ([examid] INTEGER, [rollno] integer, [answer] text, [studmark] integer,  PRIMARY KEY(rollno,examid))''')
c.execute('''CREATE TABLE gpa_db
             ([rollno] INTEGER PRIMARY KEY, [name] text, [sem] text, [gpa] integer)''')

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-2c5bda8aeb54> in <module>()
#       6 # Create table - CLIENTS
#       7 c.execute('''CREATE TABLE exam_db
# ----> 8              ([examid] INTEGER PRIMARY KEY, [subid] text, [totalmark] integer)''')
#       9 c.execute('''CREATE TABLE question_db
#      10              ([examid] INTEGER, [qno] integer, [question] text, [modelans] text, [maxmark] integer, PRIMARY KEY(examid,qno))''')
#
# OperationalError: table exam_db already exists

# %%
n=input()
n=int(n)
print(type(n))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# Insert into database

# %%
import sqlite3

try:
    sqliteConnection = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')
    cursor = sqliteConnection.cursor()
    print("Successfully Connected to evaluation_db")

    
    sqlite_insert_query = """INSERT INTO exam_db
                          (examid, subid, totalmark) 
                           VALUES (43301,'cs433',40)"""
    count = cursor.execute(sqlite_insert_query)
    sqliteConnection.commit()
    print("Record inserted successfully into exam_db table ", cursor.rowcount)

except sqlite3.Error as error:
    print("Failed to insert data into sqlite table", error)

finally:
    if (sqliteConnection):
        sqliteConnection.close()
        print("The SQLite connection is closed")
# Out:
# Successfully Connected to evaluation_db
# Record inserted successfully into exam_db table  1
# The SQLite connection is closed

# %%
import sqlite3

try:
    sqliteConnection = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')
    cursor = sqliteConnection.cursor()
    print("Successfully Connected to evaluation_db")

    sqlite_insert_query = """INSERT INTO question_db
                          (examid, qno, question, modelans, maxmark) 
                           VALUES (43301,1,'What is machine learning?','Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to perform the task. Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or infeasible to develop a conventional algorithm for effectively performing the task.',10),(43301,2,'What is mitochondrion?','Mitochondria is the power house of the cell.',20)"""
    count = cursor.execute(sqlite_insert_query)
    sqliteConnection.commit()
    print("Record inserted successfully into mark_db table ", cursor.rowcount)    
except sqlite3.Error as error:
    print("Failed to insert data into sqlite table", error)

finally:
    if (sqliteConnection):
        sqliteConnection.close()
        print("The SQLite connection is closed")
# Out:
# Successfully Connected to evaluation_db
# Record inserted successfully into mark_db table  2
# The SQLite connection is closed

# %%
import sqlite3

try:
    sqliteConnection = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')
    cursor = sqliteConnection.cursor()
    print("Successfully Connected to evaluation_db")

    sqlite_insert_query = """INSERT INTO score_db
                          (examid, rollno, qno, answer) 
                           VALUES (43301,36,1,'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to perform the task. Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or infeasible to develop a conventional algorithm for effectively performing the task'),
                           (43301,36,2,'Mitochondria is the power house of the cell'),
                           (43301,69,1,'Machine learning is train the machine'),
                           (43301,69,2,'Mitochondria is the house of the cell')"""
    count = cursor.execute(sqlite_insert_query)
    sqliteConnection.commit()
    print("Record inserted successfully into score_db table ", cursor.rowcount)    
except sqlite3.Error as error:
    print("Failed to insert data into sqlite table", error)

finally:
    if (sqliteConnection):
        sqliteConnection.close()
        print("The SQLite connection is closed")
# Out:
# Successfully Connected to evaluation_db
# Record inserted successfully into score_db table  4
# The SQLite connection is closed

# %%
import sqlite3

try:
    sqliteConnection = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')
    cursor = sqliteConnection.cursor()
    print("Successfully Connected to evaluation_db")

    sqlite_insert_query = """INSERT INTO answer_db
                          (examid, rollno, answer) 
                           VALUES (43301,36,'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to perform the task. Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or infeasible to develop a conventional algorithm for effectively performing the task*Mitochondria is the power house of the cell'),
                           (43301,69,'Machine learning is train the machine*Mitochondria is the house of the cell')
                           """
    count = cursor.execute(sqlite_insert_query)
    sqliteConnection.commit()
    print("Record inserted successfully into score_db table ", cursor.rowcount)    
except sqlite3.Error as error:
    print("Failed to insert data into sqlite table", error)

finally:
    if (sqliteConnection):
        sqliteConnection.close()
        print("The SQLite connection is closed")
# Out:
# Successfully Connected to evaluation_db
# Record inserted successfully into score_db table  2
# The SQLite connection is closed

# %%
import sqlite3

try:
    sqliteConnection = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')
    cursor = sqliteConnection.cursor()
    print("Successfully Connected to evaluation_db")

    sqlite_insert_query = """INSERT INTO gpa_db
                          (rollno, name, sem) 
                           VALUES (36,'Jilsha MK','s8cse'),
                           (69,'Sonu P','s8cse')
                           """
    count = cursor.execute(sqlite_insert_query)
    sqliteConnection.commit()
    print("Record inserted successfully into score_db table ", cursor.rowcount)    
except sqlite3.Error as error:
    print("Failed to insert data into sqlite table", error)

finally:
    if (sqliteConnection):
        sqliteConnection.close()
        print("The SQLite connection is closed")
# Out:
# Successfully Connected to evaluation_db
# Record inserted successfully into score_db table  2
# The SQLite connection is closed

# %%
import sqlite3
conn = sqlite3.connect('/content/drive/MyDrive/my_db/evaluation_db.db')  # You can create a new database by changing the name within the quotes
r_set=conn.execute('''SELECT * from exam_db''');
print("exam_db")
for row in r_set:
    print(row)
r_set=conn.execute('''SELECT * from question_db''');
print("question_db")
for row in r_set:
    print(row)
r_set=conn.execute('''SELECT * from answer_db''');
print("answer_db")
for row in r_set:
    print(row)
r_set=conn.execute('''SELECT * from score_db''');
print("score_db")
for row in r_set:
    print(row)
r_set=conn.execute('''SELECT * from gpa_db''');
print("gpa_db")
for row in r_set:
    print(row)
r_set=conn.execute('''SELECT * from teacher_db''');
print("teacher_db")
for row in r_set:
    print(row)
# Out:
# exam_db
# (43301, 'cs433', 30)
# question_db
# (43301, 1, 'What is machine learning?', 'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to perform the task. Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or infeasible to develop a conventional algorithm for effectively performing the task.', 10)
# (43301, 2, 'What is mitochondrion?', 'Mitochondria is the power house of the cell.', 20)
# ...

# %%
r_set=conn.execute('''SELECT rollno,mark from score_db''');
print("score_db")
for row in r_set:
    print(row)
# Out:
# score_db
# (36, 0)
# (36, 0)
# (69, 0)
# (69, 0)
